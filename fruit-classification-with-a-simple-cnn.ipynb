# %% [markdown]
# ## Introduction
# This kernel is a simple example of fruit classification with a simple CNN implemented with Keras model and tools. Click the blue "Edit Notebook" or "Fork Notebook" button at the top of this kernel to begin editing.

# %% [markdown]
# ## General Libs

# %%
# General Libs
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, BatchNormalization, Dropout, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import Adam, RMSprop
import numpy as np
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import tensorflow as tf; print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## Exploratory Analysis
# Let's view some dataset samples.
#
# This example uses keras ImageDataGenerator. This lib turns easier to read and use image classes from a subdirectoty structure.

# %% [markdown]
# ### Reading the dataset

# %%
im_shape = (150,150)

TRAINING_DIR = './train'
TEST_DIR = './test'

seed = 10

BATCH_SIZE = 16

# %%
#Using keras ImageGenerator and flow_from_directoty

# Subdivision in test/validation
data_generator = ImageDataGenerator(rescale=1./255, validation_split=0.2)
val_data_generator = ImageDataGenerator(rescale=1./255, validation_split=0.2)

# %%
# If you want data augmentation, uncomment and run this cell
data_generator = ImageDataGenerator(
        validation_split=0.2,
        rotation_range=20,
        width_shift_range=0.2,
        height_shift_range=0.2,
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.9,
        horizontal_flip=True,
        fill_mode='nearest')

val_data_generator = ImageDataGenerator(rescale=1./255, validation_split=0.2)

# %%
# Generator para parte train
train_generator = data_generator.flow_from_directory(TRAINING_DIR, target_size=im_shape, shuffle=True, seed=seed,
                                                     class_mode='categorical', batch_size=BATCH_SIZE, subset="training")
# Generator para parte validação
validation_generator = val_data_generator.flow_from_directory(TRAINING_DIR, target_size=im_shape, shuffle=False, seed=seed,
                                                     class_mode='categorical', batch_size=BATCH_SIZE, subset="validation")

# Generator para dataset de teste
test_generator = ImageDataGenerator(rescale=1./255)
test_generator = test_generator.flow_from_directory(TEST_DIR, target_size=im_shape, shuffle=False, seed=seed,
                                                     class_mode='categorical', batch_size=BATCH_SIZE)

nb_train_samples = train_generator.samples
nb_validation_samples = validation_generator.samples
nb_test_samples = test_generator.samples
classes = list(train_generator.class_indices.keys())
print('Classes: '+str(classes))
num_classes  = len(classes)
# Out:
# Found 72 images belonging to 6 classes.
# Found 18 images belonging to 6 classes.
# Found 30 images belonging to 6 classes.
# Classes: ['acai', 'cupuacu', 'graviola', 'guarana', 'pupunha', 'tucuma']

# %% [markdown]
# ### Showing some examples

# %%
# Visualizing some examples
plt.figure(figsize=(15,15))
for i in range(9):
    #gera subfigures
    plt.subplot(330 + 1 + i)
    batch = train_generator.__next__()[0]*255
    image = batch[0].astype('uint8')
    plt.imshow(image)
plt.show()

# %% [markdown]
# ## Creating a simple CNN Model

# %%
model = Sequential()
model.add(Conv2D(128, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=(im_shape[0],im_shape[1],3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(num_classes, activation='softmax'))
model.summary()

# Compila o modelo
model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])
# Out:
# Model: "sequential_36"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_84 (Conv2D)          (None, 148, 148, 128)     3584
#
#  max_pooling2d_83 (MaxPoolin  (None, 74, 74, 128)      0
#  g2D)
#
#  conv2d_85 (Conv2D)          (None, 72, 72, 64)        73792
#
#  max_pooling2d_84 (MaxPoolin  (None, 36, 36, 64)       0
#  g2D)
#
#  conv2d_86 (Conv2D)          (None, 34, 34, 64)        36928
#
#  max_pooling2d_85 (MaxPoolin  (None, 17, 17, 64)       0
#  g2D)
#
#  flatten_36 (Flatten)        (None, 18496)             0
#
#  dense_144 (Dense)           (None, 512)               9470464
#
#  dropout_108 (Dropout)       (None, 512)               0
#
#  dense_145 (Dense)           (None, 256)               131328
#
#  dropout_109 (Dropout)       (None, 256)               0
#
#  dense_146 (Dense)           (None, 32)                8224
#
#  dropout_110 (Dropout)       (None, 32)                0
#
#  dense_147 (Dense)           (None, 6)                 198
#
# =================================================================
# Total params: 9,724,518
# Trainable params: 9,724,518
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 150

#Callback to save the best model 
callbacks_list = [
    keras.callbacks.ModelCheckpoint(
        filepath='model.keras',
        monitor='val_loss', save_best_only=True, verbose=1),
    keras.callbacks.EarlyStopping(monitor='val_loss', patience=20,verbose=1)
]

#Training
history = model.fit(
            train_generator,
            steps_per_epoch=nb_train_samples // BATCH_SIZE,
            epochs=epochs,
            callbacks = callbacks_list,
            validation_data=validation_generator,
            verbose = 1,
            validation_steps=nb_validation_samples // BATCH_SIZE
        )
# Out:
# Epoch 1/150
# 4/4 [==============================] - ETA: 0s - loss: 3.2180 - accuracy: 0.1607
# Epoch 1: val_loss improved from inf to 1.79166, saving model to model.keras
# 4/4 [==============================] - 2s 255ms/step - loss: 3.2180 - accuracy: 0.1607 - val_loss: 1.7917 - val_accuracy: 0.0625
# Epoch 2/150
# 4/4 [==============================] - ETA: 0s - loss: 1.8037 - accuracy: 0.1607
# Epoch 2: val_loss improved from 1.79166 to 1.78813, saving model to model.keras
# 4/4 [==============================] - 1s 199ms/step - loss: 1.8037 - accuracy: 0.1607 - val_loss: 1.7881 - val_accuracy: 0.1875
# Epoch 3/150
# 4/4 [==============================] - ETA: 0s - loss: 1.7851 - accuracy: 0.2857
# Epoch 3: val_loss improved from 1.78813 to 1.76392, saving model to model.keras
# 4/4 [==============================] - 1s 169ms/step - loss: 1.7851 - accuracy: 0.2857 - val_loss: 1.7639 - val_accuracy: 0.1875
# Epoch 4/150
# 4/4 [==============================] - ETA: 0s - loss: 1.8172 - accuracy: 0.1429
# Epoch 4: val_loss improved from 1.76392 to 1.73821, saving model to model.keras
# 4/4 [==============================] - 1s 181ms/step - loss: 1.8172 - accuracy: 0.1429 - val_loss: 1.7382 - val_accuracy: 0.1875
# Epoch 5/150
# 4/4 [==============================] - ETA: 0s - loss: 1.7645 - accuracy: 0.1719
# Epoch 5: val_loss improved from 1.73821 to 1.58446, saving model to model.keras
# 4/4 [==============================] - 1s 187ms/step - loss: 1.7645 - accuracy: 0.1719 - val_loss: 1.5845 - val_accuracy: 0.1875
# Epoch 6/150
# 4/4 [==============================] - ETA: 0s - loss: 1.8531 - accuracy: 0.1250
# Epoch 6: val_loss did not improve from 1.58446
# 4/4 [==============================] - 0s 108ms/step - loss: 1.8531 - accuracy: 0.1250 - val_loss: 1.7489 - val_accuracy: 0.2500
# Epoch 7/150
# 4/4 [==============================] - ETA: 0s - loss: 1.7652 - accuracy: 0.2857
# Epoch 7: val_loss did not improve from 1.58446
# 4/4 [==============================] - 0s 89ms/step - loss: 1.7652 - accuracy: 0.2857 - val_loss: 1.6190 - val_accuracy: 0.1875
# Epoch 8/150
# 4/4 [==============================] - ETA: 0s - loss: 1.7091 - accuracy: 0.2321
# Epoch 8: val_loss improved from 1.58446 to 1.52039, saving model to model.keras
# 4/4 [==============================] - 1s 184ms/step - loss: 1.7091 - accuracy: 0.2321 - val_loss: 1.5204 - val_accuracy: 0.1875
# Epoch 9/150
# 3/4 [=====================>........] - ETA: 0s - loss: 1.7202 - accuracy: 0.2083
# Epoch 9: val_loss did not improve from 1.52039
# 4/4 [==============================] - 0s 83ms/step - loss: 1.7228 - accuracy: 0.2321 - val_loss: 1.6177 - val_accuracy: 0.1875
# Epoch 10/150
# 4/4 [==============================] - ETA: 0s - loss: 1.7253 - accuracy: 0.3036
# Epoch 10: val_loss improved from 1.52039 to 1.51321, saving model to model.keras
# 4/4 [==============================] - 1s 164ms/step - loss: 1.7253 - accuracy: 0.3036 - val_loss: 1.5132 - val_accuracy: 0.2500
# Epoch 11/150
# 4/4 [==============================] - ETA: 0s - loss: 1.6909 - accuracy: 0.2812
# Epoch 11: val_loss did not improve from 1.51321
# 4/4 [==============================] - 0s 100ms/step - loss: 1.6909 - accuracy: 0.2812 - val_loss: 1.5261 - val_accuracy: 0.2500
# Epoch 12/150
# 4/4 [==============================] - ETA: 0s - loss: 2.0687 - accuracy: 0.1786
# Epoch 12: val_loss did not improve from 1.51321
# 4/4 [==============================] - 0s 91ms/step - loss: 2.0687 - accuracy: 0.1786 - val_loss: 1.6856 - val_accuracy: 0.4375
# Epoch 13/150
# 4/4 [==============================] - ETA: 0s - loss: 1.6754 - accuracy: 0.3393
# Epoch 13: val_loss improved from 1.51321 to 1.46911, saving model to model.keras
# 4/4 [==============================] - 1s 166ms/step - loss: 1.6754 - accuracy: 0.3393 - val_loss: 1.4691 - val_accuracy: 0.3125
# Epoch 14/150
# 4/4 [==============================] - ETA: 0s - loss: 1.6260 - accuracy: 0.2857
# Epoch 14: val_loss improved from 1.46911 to 1.40961, saving model to model.keras
# 4/4 [==============================] - 1s 187ms/step - loss: 1.6260 - accuracy: 0.2857 - val_loss: 1.4096 - val_accuracy: 0.2500
# Epoch 15/150
# 3/4 [=====================>........] - ETA: 0s - loss: 1.5521 - accuracy: 0.3333
# Epoch 15: val_loss improved from 1.40961 to 1.40693, saving model to model.keras
# 4/4 [==============================] - 1s 173ms/step - loss: 1.5377 - accuracy: 0.3393 - val_loss: 1.4069 - val_accuracy: 0.3750
# Epoch 16/150
# 4/4 [==============================] - ETA: 0s - loss: 1.6134 - accuracy: 0.3036
# Epoch 16: val_loss improved from 1.40693 to 1.29628, saving model to model.keras
# 4/4 [==============================] - 1s 168ms/step - loss: 1.6134 - accuracy: 0.3036 - val_loss: 1.2963 - val_accuracy: 0.5625
# Epoch 17/150
# 3/4 [=====================>........] - ETA: 0s - loss: 1.5544 - accuracy: 0.3333
# Epoch 17: val_loss did not improve from 1.29628
# 4/4 [==============================] - 0s 85ms/step - loss: 1.5467 - accuracy: 0.3214 - val_loss: 1.4809 - val_accuracy: 0.3750
# Epoch 18/150
# 4/4 [==============================] - ETA: 0s - loss: 1.5522 - accuracy: 0.2679
# Epoch 18: val_loss did not improve from 1.29628
# 4/4 [==============================] - 0s 88ms/step - loss: 1.5522 - accuracy: 0.2679 - val_loss: 1.4902 - val_accuracy: 0.1875
# Epoch 19/150
# 4/4 [==============================] - ETA: 0s - loss: 1.5282 - accuracy: 0.3036
# Epoch 19: val_loss did not improve from 1.29628
# 4/4 [==============================] - 0s 89ms/step - loss: 1.5282 - accuracy: 0.3036 - val_loss: 1.5612 - val_accuracy: 0.4375
# Epoch 20/150
# 3/4 [=====================>........] - ETA: 0s - loss: 1.5244 - accuracy: 0.4375
# Epoch 20: val_loss did not improve from 1.29628
# 4/4 [==============================] - 0s 82ms/step - loss: 1.5680 - accuracy: 0.4286 - val_loss: 1.6247 - val_accuracy: 0.3750
# Epoch 21/150
# 4/4 [==============================] - ETA: 0s - loss: 1.5296 - accuracy: 0.4464
# Epoch 21: val_loss did not improve from 1.29628
# 4/4 [==============================] - 0s 88ms/step - loss: 1.5296 - accuracy: 0.4464 - val_loss: 1.5345 - val_accuracy: 0.3750
# Epoch 22/150
# 4/4 [==============================] - ETA: 0s - loss: 1.3855 - accuracy: 0.3929
# Epoch 22: val_loss improved from 1.29628 to 1.03844, saving model to model.keras
# 4/4 [==============================] - 1s 204ms/step - loss: 1.3855 - accuracy: 0.3929 - val_loss: 1.0384 - val_accuracy: 0.5625
# Epoch 23/150
# 3/4 [=====================>........] - ETA: 0s - loss: 1.2533 - accuracy: 0.4792
# Epoch 23: val_loss did not improve from 1.03844
# 4/4 [==============================] - 0s 89ms/step - loss: 1.2147 - accuracy: 0.5000 - val_loss: 1.1817 - val_accuracy: 0.5000
# Epoch 24/150
# 4/4 [==============================] - ETA: 0s - loss: 1.4230 - accuracy: 0.3750
# Epoch 24: val_loss did not improve from 1.03844
# 4/4 [==============================] - 0s 101ms/step - loss: 1.4230 - accuracy: 0.3750 - val_loss: 1.2969 - val_accuracy: 0.4375
# Epoch 25/150
# 4/4 [==============================] - ETA: 0s - loss: 1.3487 - accuracy: 0.4219
# Epoch 25: val_loss improved from 1.03844 to 1.02882, saving model to model.keras
# 4/4 [==============================] - 1s 175ms/step - loss: 1.3487 - accuracy: 0.4219 - val_loss: 1.0288 - val_accuracy: 0.5625
# Epoch 26/150
# 4/4 [==============================] - ETA: 0s - loss: 3.3529 - accuracy: 0.4286
# Epoch 26: val_loss did not improve from 1.02882
# 4/4 [==============================] - 0s 87ms/step - loss: 3.3529 - accuracy: 0.4286 - val_loss: 1.2753 - val_accuracy: 0.5625
# Epoch 27/150
# 3/4 [=====================>........] - ETA: 0s - loss: 1.4071 - accuracy: 0.4792
# Epoch 27: val_loss did not improve from 1.02882
# 4/4 [==============================] - 0s 84ms/step - loss: 1.3543 - accuracy: 0.4821 - val_loss: 1.4046 - val_accuracy: 0.5000
# Epoch 28/150
# 4/4 [==============================] - ETA: 0s - loss: 1.2505 - accuracy: 0.4821
# Epoch 28: val_loss improved from 1.02882 to 0.98603, saving model to model.keras
# 4/4 [==============================] - 1s 161ms/step - loss: 1.2505 - accuracy: 0.4821 - val_loss: 0.9860 - val_accuracy: 0.5625
# Epoch 29/150
# 4/4 [==============================] - ETA: 0s - loss: 1.1873 - accuracy: 0.5000
# Epoch 29: val_loss did not improve from 0.98603
# 4/4 [==============================] - 0s 106ms/step - loss: 1.1873 - accuracy: 0.5000 - val_loss: 1.1295 - val_accuracy: 0.5625
# Epoch 30/150
# 4/4 [==============================] - ETA: 0s - loss: 1.2119 - accuracy: 0.4643
# Epoch 30: val_loss improved from 0.98603 to 0.87072, saving model to model.keras
# 4/4 [==============================] - 1s 169ms/step - loss: 1.2119 - accuracy: 0.4643 - val_loss: 0.8707 - val_accuracy: 0.5625
# Epoch 31/150
# 4/4 [==============================] - ETA: 0s - loss: 0.9910 - accuracy: 0.5156
# Epoch 31: val_loss did not improve from 0.87072
# 4/4 [==============================] - 0s 104ms/step - loss: 0.9910 - accuracy: 0.5156 - val_loss: 1.2301 - val_accuracy: 0.6875
# Epoch 32/150
# 4/4 [==============================] - ETA: 0s - loss: 1.3641 - accuracy: 0.5179
# Epoch 32: val_loss did not improve from 0.87072
# 4/4 [==============================] - 0s 107ms/step - loss: 1.3641 - accuracy: 0.5179 - val_loss: 0.9098 - val_accuracy: 0.5625
# Epoch 33/150
# 4/4 [==============================] - ETA: 0s - loss: 1.1436 - accuracy: 0.5179
# Epoch 33: val_loss did not improve from 0.87072
# 4/4 [==============================] - 0s 89ms/step - loss: 1.1436 - accuracy: 0.5179 - val_loss: 1.0377 - val_accuracy: 0.5625
# Epoch 34/150
# 4/4 [==============================] - ETA: 0s - loss: 1.2728 - accuracy: 0.3750
# Epoch 34: val_loss improved from 0.87072 to 0.86522, saving model to model.keras
# 4/4 [==============================] - 1s 165ms/step - loss: 1.2728 - accuracy: 0.3750 - val_loss: 0.8652 - val_accuracy: 0.6875
# Epoch 35/150
# 4/4 [==============================] - ETA: 0s - loss: 1.2403 - accuracy: 0.6250
# Epoch 35: val_loss did not improve from 0.86522
# 4/4 [==============================] - 0s 89ms/step - loss: 1.2403 - accuracy: 0.6250 - val_loss: 1.5810 - val_accuracy: 0.3125
# Epoch 36/150
# 3/4 [=====================>........] - ETA: 0s - loss: 1.2656 - accuracy: 0.4375
# Epoch 36: val_loss did not improve from 0.86522
# 4/4 [==============================] - 0s 84ms/step - loss: 1.2684 - accuracy: 0.4286 - val_loss: 0.8755 - val_accuracy: 0.5000
# Epoch 37/150
# 4/4 [==============================] - ETA: 0s - loss: 1.2905 - accuracy: 0.4375
# Epoch 37: val_loss did not improve from 0.86522
# 4/4 [==============================] - 0s 104ms/step - loss: 1.2905 - accuracy: 0.4375 - val_loss: 1.0289 - val_accuracy: 0.5625
# Epoch 38/150
# 4/4 [==============================] - ETA: 0s - loss: 1.1598 - accuracy: 0.5357
# Epoch 38: val_loss improved from 0.86522 to 0.84096, saving model to model.keras
# 4/4 [==============================] - 1s 163ms/step - loss: 1.1598 - accuracy: 0.5357 - val_loss: 0.8410 - val_accuracy: 0.7500
# Epoch 39/150
# 3/4 [=====================>........] - ETA: 0s - loss: 1.0050 - accuracy: 0.6042
# Epoch 39: val_loss did not improve from 0.84096
# 4/4 [==============================] - 0s 86ms/step - loss: 0.9846 - accuracy: 0.6250 - val_loss: 1.0908 - val_accuracy: 0.5625
# Epoch 40/150
# 4/4 [==============================] - ETA: 0s - loss: 1.0423 - accuracy: 0.6250
# Epoch 40: val_loss did not improve from 0.84096
# 4/4 [==============================] - 0s 106ms/step - loss: 1.0423 - accuracy: 0.6250 - val_loss: 1.0079 - val_accuracy: 0.5000
# Epoch 41/150
# 4/4 [==============================] - ETA: 0s - loss: 1.2058 - accuracy: 0.5714
# Epoch 41: val_loss did not improve from 0.84096
# 4/4 [==============================] - 0s 89ms/step - loss: 1.2058 - accuracy: 0.5714 - val_loss: 1.1668 - val_accuracy: 0.5625
# Epoch 42/150
# 4/4 [==============================] - ETA: 0s - loss: 1.2314 - accuracy: 0.5000
# Epoch 42: val_loss did not improve from 0.84096
# 4/4 [==============================] - 0s 88ms/step - loss: 1.2314 - accuracy: 0.5000 - val_loss: 0.8588 - val_accuracy: 0.6250
# Epoch 43/150
# 4/4 [==============================] - ETA: 0s - loss: 0.8065 - accuracy: 0.6964
# Epoch 43: val_loss did not improve from 0.84096
# 4/4 [==============================] - 0s 92ms/step - loss: 0.8065 - accuracy: 0.6964 - val_loss: 0.8928 - val_accuracy: 0.5625
# Epoch 44/150
# 4/4 [==============================] - ETA: 0s - loss: 1.1921 - accuracy: 0.5893
# Epoch 44: val_loss improved from 0.84096 to 0.72745, saving model to model.keras
# 4/4 [==============================] - 1s 164ms/step - loss: 1.1921 - accuracy: 0.5893 - val_loss: 0.7274 - val_accuracy: 0.6875
# Epoch 45/150
# 4/4 [==============================] - ETA: 0s - loss: 1.0506 - accuracy: 0.5536
# Epoch 45: val_loss did not improve from 0.72745
# 4/4 [==============================] - 0s 89ms/step - loss: 1.0506 - accuracy: 0.5536 - val_loss: 0.7490 - val_accuracy: 0.6875
# Epoch 46/150
# 4/4 [==============================] - ETA: 0s - loss: 1.3356 - accuracy: 0.5357
# Epoch 46: val_loss did not improve from 0.72745
# 4/4 [==============================] - 0s 110ms/step - loss: 1.3356 - accuracy: 0.5357 - val_loss: 0.9030 - val_accuracy: 0.5625
# Epoch 47/150
# 3/4 [=====================>........] - ETA: 0s - loss: 0.8486 - accuracy: 0.7083
# Epoch 47: val_loss did not improve from 0.72745
# 4/4 [==============================] - 0s 86ms/step - loss: 0.9429 - accuracy: 0.6964 - val_loss: 0.8016 - val_accuracy: 0.5000
# Epoch 48/150
# 4/4 [==============================] - ETA: 0s - loss: 1.0111 - accuracy: 0.5536
# Epoch 48: val_loss did not improve from 0.72745
# 4/4 [==============================] - 0s 90ms/step - loss: 1.0111 - accuracy: 0.5536 - val_loss: 0.7845 - val_accuracy: 0.6250
# Epoch 49/150
# 3/4 [=====================>........] - ETA: 0s - loss: 0.9678 - accuracy: 0.5417
# Epoch 49: val_loss did not improve from 0.72745
# 4/4 [==============================] - 0s 87ms/step - loss: 0.9417 - accuracy: 0.5893 - val_loss: 1.6110 - val_accuracy: 0.4375
# Epoch 50/150
# 4/4 [==============================] - ETA: 0s - loss: 1.7095 - accuracy: 0.4821
# Epoch 50: val_loss did not improve from 0.72745
# 4/4 [==============================] - 0s 88ms/step - loss: 1.7095 - accuracy: 0.4821 - val_loss: 1.3088 - val_accuracy: 0.5625
# Epoch 51/150
# 3/4 [=====================>........] - ETA: 0s - loss: 0.9433 - accuracy: 0.6458
# Epoch 51: val_loss improved from 0.72745 to 0.67178, saving model to model.keras
# 4/4 [==============================] - 1s 172ms/step - loss: 0.9370 - accuracy: 0.6607 - val_loss: 0.6718 - val_accuracy: 0.9375
# Epoch 52/150
# 3/4 [=====================>........] - ETA: 0s - loss: 1.1118 - accuracy: 0.5417
# Epoch 52: val_loss did not improve from 0.67178
# 4/4 [==============================] - 0s 85ms/step - loss: 1.0868 - accuracy: 0.5357 - val_loss: 1.1320 - val_accuracy: 0.6875
# Epoch 53/150
# 4/4 [==============================] - ETA: 0s - loss: 0.6965 - accuracy: 0.6964
# Epoch 53: val_loss did not improve from 0.67178
# 4/4 [==============================] - 0s 90ms/step - loss: 0.6965 - accuracy: 0.6964 - val_loss: 0.8750 - val_accuracy: 0.6875
# Epoch 54/150
# 4/4 [==============================] - ETA: 0s - loss: 1.1877 - accuracy: 0.5625
# Epoch 54: val_loss did not improve from 0.67178
# 4/4 [==============================] - 0s 103ms/step - loss: 1.1877 - accuracy: 0.5625 - val_loss: 0.7515 - val_accuracy: 0.8750
# Epoch 55/150
# 4/4 [==============================] - ETA: 0s - loss: 0.7425 - accuracy: 0.7143
# Epoch 55: val_loss improved from 0.67178 to 0.63590, saving model to model.keras
# 4/4 [==============================] - 1s 164ms/step - loss: 0.7425 - accuracy: 0.7143 - val_loss: 0.6359 - val_accuracy: 0.6875
# Epoch 56/150
# 4/4 [==============================] - ETA: 0s - loss: 0.6993 - accuracy: 0.7031
# Epoch 56: val_loss did not improve from 0.63590
# 4/4 [==============================] - 0s 105ms/step - loss: 0.6993 - accuracy: 0.7031 - val_loss: 1.3175 - val_accuracy: 0.5625
# Epoch 57/150
# 4/4 [==============================] - ETA: 0s - loss: 1.0321 - accuracy: 0.6071
# Epoch 57: val_loss did not improve from 0.63590
# 4/4 [==============================] - 0s 90ms/step - loss: 1.0321 - accuracy: 0.6071 - val_loss: 0.8043 - val_accuracy: 0.6250
# Epoch 58/150
# 4/4 [==============================] - ETA: 0s - loss: 1.1386 - accuracy: 0.5156
# Epoch 58: val_loss did not improve from 0.63590
# 4/4 [==============================] - 0s 98ms/step - loss: 1.1386 - accuracy: 0.5156 - val_loss: 0.7228 - val_accuracy: 0.6875
# Epoch 59/150
# 3/4 [=====================>........] - ETA: 0s - loss: 0.8742 - accuracy: 0.6667
# Epoch 59: val_loss did not improve from 0.63590
# 4/4 [==============================] - 0s 86ms/step - loss: 0.8215 - accuracy: 0.6786 - val_loss: 5.7531 - val_accuracy: 0.2500
# Epoch 60/150
# 3/4 [=====================>........] - ETA: 0s - loss: 3.0223 - accuracy: 0.3333
# Epoch 60: val_loss did not improve from 0.63590
# 4/4 [==============================] - 0s 86ms/step - loss: 2.7066 - accuracy: 0.3571 - val_loss: 1.0086 - val_accuracy: 0.5000
# Epoch 61/150
# 4/4 [==============================] - ETA: 0s - loss: 0.9340 - accuracy: 0.6786
# Epoch 61: val_loss did not improve from 0.63590
# 4/4 [==============================] - 0s 110ms/step - loss: 0.9340 - accuracy: 0.6786 - val_loss: 0.6908 - val_accuracy: 0.8125
# Epoch 62/150
# 4/4 [==============================] - ETA: 0s - loss: 0.7101 - accuracy: 0.7031
# Epoch 62: val_loss did not improve from 0.63590
# 4/4 [==============================] - 0s 100ms/step - loss: 0.7101 - accuracy: 0.7031 - val_loss: 0.7505 - val_accuracy: 0.6250
# Epoch 63/150
# 3/4 [=====================>........] - ETA: 0s - loss: 0.8970 - accuracy: 0.7292
# Epoch 63: val_loss did not improve from 0.63590
# 4/4 [==============================] - 0s 89ms/step - loss: 0.8398 - accuracy: 0.7321 - val_loss: 0.8173 - val_accuracy: 0.6875
# Epoch 64/150
# 4/4 [==============================] - ETA: 0s - loss: 0.6636 - accuracy: 0.7143
# Epoch 64: val_loss did not improve from 0.63590
# 4/4 [==============================] - 0s 89ms/step - loss: 0.6636 - accuracy: 0.7143 - val_loss: 0.9017 - val_accuracy: 0.6250
# Epoch 65/150
# 3/4 [=====================>........] - ETA: 0s - loss: 1.0154 - accuracy: 0.5833
# Epoch 65: val_loss did not improve from 0.63590
# 4/4 [==============================] - 0s 84ms/step - loss: 1.0061 - accuracy: 0.5893 - val_loss: 0.6840 - val_accuracy: 0.7500
# Epoch 66/150
# 4/4 [==============================] - ETA: 0s - loss: 0.8909 - accuracy: 0.6250
# Epoch 66: val_loss improved from 0.63590 to 0.62801, saving model to model.keras
# 4/4 [==============================] - 1s 187ms/step - loss: 0.8909 - accuracy: 0.6250 - val_loss: 0.6280 - val_accuracy: 0.7500
# Epoch 67/150
# 4/4 [==============================] - ETA: 0s - loss: 0.9714 - accuracy: 0.5893
# Epoch 67: val_loss did not improve from 0.62801
# 4/4 [==============================] - 0s 98ms/step - loss: 0.9714 - accuracy: 0.5893 - val_loss: 1.1693 - val_accuracy: 0.5625
# Epoch 68/150
# 3/4 [=====================>........] - ETA: 0s - loss: 0.6718 - accuracy: 0.7292
# Epoch 68: val_loss did not improve from 0.62801
# 4/4 [==============================] - 0s 84ms/step - loss: 0.6811 - accuracy: 0.7143 - val_loss: 0.7500 - val_accuracy: 0.6250
# Epoch 69/150
# 4/4 [==============================] - ETA: 0s - loss: 0.8099 - accuracy: 0.6964
# Epoch 69: val_loss did not improve from 0.62801
# 4/4 [==============================] - 0s 92ms/step - loss: 0.8099 - accuracy: 0.6964 - val_loss: 0.6565 - val_accuracy: 0.6875
# Epoch 70/150
# 4/4 [==============================] - ETA: 0s - loss: 0.9714 - accuracy: 0.5714
# Epoch 70: val_loss did not improve from 0.62801
# 4/4 [==============================] - 0s 107ms/step - loss: 0.9714 - accuracy: 0.5714 - val_loss: 0.6489 - val_accuracy: 0.7500
# Epoch 71/150
# 4/4 [==============================] - ETA: 0s - loss: 0.7837 - accuracy: 0.6071
# Epoch 71: val_loss improved from 0.62801 to 0.60983, saving model to model.keras
# 4/4 [==============================] - 1s 183ms/step - loss: 0.7837 - accuracy: 0.6071 - val_loss: 0.6098 - val_accuracy: 0.8750
# Epoch 72/150
# 4/4 [==============================] - ETA: 0s - loss: 0.8112 - accuracy: 0.7500
# Epoch 72: val_loss did not improve from 0.60983
# 4/4 [==============================] - 0s 105ms/step - loss: 0.8112 - accuracy: 0.7500 - val_loss: 0.9212 - val_accuracy: 0.6250
# Epoch 73/150
# 4/4 [==============================] - ETA: 0s - loss: 0.6872 - accuracy: 0.7321
# Epoch 73: val_loss did not improve from 0.60983
# 4/4 [==============================] - 0s 110ms/step - loss: 0.6872 - accuracy: 0.7321 - val_loss: 0.7536 - val_accuracy: 0.7500
# Epoch 74/150
# 3/4 [=====================>........] - ETA: 0s - loss: 1.5384 - accuracy: 0.6667
# Epoch 74: val_loss did not improve from 0.60983
# 4/4 [==============================] - 0s 86ms/step - loss: 1.4707 - accuracy: 0.6429 - val_loss: 1.0884 - val_accuracy: 0.6250
# Epoch 75/150
# 4/4 [==============================] - ETA: 0s - loss: 0.9481 - accuracy: 0.6071
# Epoch 75: val_loss did not improve from 0.60983
# 4/4 [==============================] - 0s 92ms/step - loss: 0.9481 - accuracy: 0.6071 - val_loss: 0.6748 - val_accuracy: 0.8125
# Epoch 76/150
# 3/4 [=====================>........] - ETA: 0s - loss: 0.7182 - accuracy: 0.7083
# Epoch 76: val_loss did not improve from 0.60983
# 4/4 [==============================] - 0s 88ms/step - loss: 0.7245 - accuracy: 0.6964 - val_loss: 1.0500 - val_accuracy: 0.5000
# Epoch 77/150
# 4/4 [==============================] - ETA: 0s - loss: 0.7352 - accuracy: 0.7500
# Epoch 77: val_loss did not improve from 0.60983
# 4/4 [==============================] - 0s 88ms/step - loss: 0.7352 - accuracy: 0.7500 - val_loss: 0.7564 - val_accuracy: 0.8125
# Epoch 78/150
# 4/4 [==============================] - ETA: 0s - loss: 0.7175 - accuracy: 0.7143
# Epoch 78: val_loss improved from 0.60983 to 0.46590, saving model to model.keras
# 4/4 [==============================] - 1s 172ms/step - loss: 0.7175 - accuracy: 0.7143 - val_loss: 0.4659 - val_accuracy: 0.9375
# Epoch 79/150
# 4/4 [==============================] - ETA: 0s - loss: 1.2004 - accuracy: 0.6429
# Epoch 79: val_loss did not improve from 0.46590
# 4/4 [==============================] - 0s 91ms/step - loss: 1.2004 - accuracy: 0.6429 - val_loss: 1.0493 - val_accuracy: 0.5625
# Epoch 80/150
# 4/4 [==============================] - ETA: 0s - loss: 0.6060 - accuracy: 0.7321
# Epoch 80: val_loss did not improve from 0.46590
# 4/4 [==============================] - 0s 89ms/step - loss: 0.6060 - accuracy: 0.7321 - val_loss: 0.6534 - val_accuracy: 0.8750
# Epoch 81/150
# 3/4 [=====================>........] - ETA: 0s - loss: 1.3545 - accuracy: 0.6667
# Epoch 81: val_loss did not improve from 0.46590
# 4/4 [==============================] - 0s 88ms/step - loss: 1.3669 - accuracy: 0.6250 - val_loss: 0.8668 - val_accuracy: 0.8125
# Epoch 82/150
# 4/4 [==============================] - ETA: 0s - loss: 0.8461 - accuracy: 0.6429
# Epoch 82: val_loss did not improve from 0.46590
# 4/4 [==============================] - 0s 111ms/step - loss: 0.8461 - accuracy: 0.6429 - val_loss: 0.6125 - val_accuracy: 0.8125
# Epoch 83/150
# 4/4 [==============================] - ETA: 0s - loss: 0.8135 - accuracy: 0.7143
# Epoch 83: val_loss did not improve from 0.46590
# 4/4 [==============================] - 0s 107ms/step - loss: 0.8135 - accuracy: 0.7143 - val_loss: 0.5764 - val_accuracy: 0.8750
# Epoch 84/150
# 3/4 [=====================>........] - ETA: 0s - loss: 0.6654 - accuracy: 0.7292
# Epoch 84: val_loss did not improve from 0.46590
# 4/4 [==============================] - 0s 85ms/step - loss: 0.7471 - accuracy: 0.7143 - val_loss: 1.3460 - val_accuracy: 0.5000
# Epoch 85/150
# 4/4 [==============================] - ETA: 0s - loss: 0.7087 - accuracy: 0.7031
# Epoch 85: val_loss did not improve from 0.46590
# 4/4 [==============================] - 0s 100ms/step - loss: 0.7087 - accuracy: 0.7031 - val_loss: 0.8486 - val_accuracy: 0.6250
# Epoch 86/150
# 4/4 [==============================] - ETA: 0s - loss: 0.7663 - accuracy: 0.7143
# Epoch 86: val_loss improved from 0.46590 to 0.42847, saving model to model.keras
# 4/4 [==============================] - 1s 213ms/step - loss: 0.7663 - accuracy: 0.7143 - val_loss: 0.4285 - val_accuracy: 0.9375
# Epoch 87/150
# 4/4 [==============================] - ETA: 0s - loss: 0.7156 - accuracy: 0.7344
# Epoch 87: val_loss did not improve from 0.42847
# 4/4 [==============================] - 0s 103ms/step - loss: 0.7156 - accuracy: 0.7344 - val_loss: 1.4867 - val_accuracy: 0.4375
# Epoch 88/150
# 4/4 [==============================] - ETA: 0s - loss: 0.8604 - accuracy: 0.7188
# Epoch 88: val_loss did not improve from 0.42847
# 4/4 [==============================] - 0s 99ms/step - loss: 0.8604 - accuracy: 0.7188 - val_loss: 0.4455 - val_accuracy: 0.8750
# Epoch 89/150
# 4/4 [==============================] - ETA: 0s - loss: 0.6106 - accuracy: 0.7500
# Epoch 89: val_loss did not improve from 0.42847
# 4/4 [==============================] - 0s 107ms/step - loss: 0.6106 - accuracy: 0.7500 - val_loss: 0.6329 - val_accuracy: 0.7500
# Epoch 90/150
# 4/4 [==============================] - ETA: 0s - loss: 0.9333 - accuracy: 0.6875
# Epoch 90: val_loss did not improve from 0.42847
# 4/4 [==============================] - 0s 99ms/step - loss: 0.9333 - accuracy: 0.6875 - val_loss: 0.6752 - val_accuracy: 0.6875
# Epoch 91/150
# 4/4 [==============================] - ETA: 0s - loss: 0.4954 - accuracy: 0.8393
# Epoch 91: val_loss did not improve from 0.42847
# 4/4 [==============================] - 0s 89ms/step - loss: 0.4954 - accuracy: 0.8393 - val_loss: 0.5141 - val_accuracy: 0.8125
# Epoch 92/150
# 4/4 [==============================] - ETA: 0s - loss: 0.9858 - accuracy: 0.6071
# Epoch 92: val_loss did not improve from 0.42847
# 4/4 [==============================] - 0s 108ms/step - loss: 0.9858 - accuracy: 0.6071 - val_loss: 0.6839 - val_accuracy: 0.7500
# Epoch 93/150
# 4/4 [==============================] - ETA: 0s - loss: 0.8802 - accuracy: 0.6786
# Epoch 93: val_loss did not improve from 0.42847
# 4/4 [==============================] - 0s 95ms/step - loss: 0.8802 - accuracy: 0.6786 - val_loss: 1.1531 - val_accuracy: 0.5625
# Epoch 94/150
# 3/4 [=====================>........] - ETA: 0s - loss: 0.7310 - accuracy: 0.6667
# Epoch 94: val_loss did not improve from 0.42847
# 4/4 [==============================] - 0s 81ms/step - loss: 0.8635 - accuracy: 0.6429 - val_loss: 0.8381 - val_accuracy: 0.6875
# Epoch 95/150
# 4/4 [==============================] - ETA: 0s - loss: 0.6553 - accuracy: 0.7812
# Epoch 95: val_loss did not improve from 0.42847
# 4/4 [==============================] - 0s 102ms/step - loss: 0.6553 - accuracy: 0.7812 - val_loss: 0.5498 - val_accuracy: 0.7500
# Epoch 96/150
# 4/4 [==============================] - ETA: 0s - loss: 1.2187 - accuracy: 0.7321
# Epoch 96: val_loss did not improve from 0.42847
# 4/4 [==============================] - 0s 91ms/step - loss: 1.2187 - accuracy: 0.7321 - val_loss: 1.7731 - val_accuracy: 0.3125
# Epoch 97/150
# 3/4 [=====================>........] - ETA: 0s - loss: 0.9151 - accuracy: 0.5833
# Epoch 97: val_loss did not improve from 0.42847
# 4/4 [==============================] - 0s 83ms/step - loss: 0.9083 - accuracy: 0.5893 - val_loss: 0.7327 - val_accuracy: 0.7500
# Epoch 98/150
# 4/4 [==============================] - ETA: 0s - loss: 0.8502 - accuracy: 0.6429
# Epoch 98: val_loss did not improve from 0.42847
# 4/4 [==============================] - 0s 89ms/step - loss: 0.8502 - accuracy: 0.6429 - val_loss: 0.5720 - val_accuracy: 0.8750
# Epoch 99/150
# 4/4 [==============================] - ETA: 0s - loss: 0.9870 - accuracy: 0.6786
# Epoch 99: val_loss did not improve from 0.42847
# 4/4 [==============================] - 0s 93ms/step - loss: 0.9870 - accuracy: 0.6786 - val_loss: 0.8056 - val_accuracy: 0.7500
# Epoch 100/150
# 4/4 [==============================] - ETA: 0s - loss: 0.7154 - accuracy: 0.6875
# Epoch 100: val_loss did not improve from 0.42847
# 4/4 [==============================] - 0s 99ms/step - loss: 0.7154 - accuracy: 0.6875 - val_loss: 0.9750 - val_accuracy: 0.6250
# Epoch 101/150
# 4/4 [==============================] - ETA: 0s - loss: 1.1266 - accuracy: 0.6607
# Epoch 101: val_loss did not improve from 0.42847
# 4/4 [==============================] - 0s 95ms/step - loss: 1.1266 - accuracy: 0.6607 - val_loss: 0.7288 - val_accuracy: 0.8125
# Epoch 102/150
# 4/4 [==============================] - ETA: 0s - loss: 0.6692 - accuracy: 0.7679
# Epoch 102: val_loss did not improve from 0.42847
# 4/4 [==============================] - 0s 112ms/step - loss: 0.6692 - accuracy: 0.7679 - val_loss: 0.5490 - val_accuracy: 0.8125
# Epoch 103/150
# 4/4 [==============================] - ETA: 0s - loss: 0.5077 - accuracy: 0.7857
# Epoch 103: val_loss did not improve from 0.42847
# 4/4 [==============================] - 0s 98ms/step - loss: 0.5077 - accuracy: 0.7857 - val_loss: 0.7148 - val_accuracy: 0.8125
# Epoch 104/150
# 4/4 [==============================] - ETA: 0s - loss: 0.7765 - accuracy: 0.7500
# Epoch 104: val_loss did not improve from 0.42847
# 4/4 [==============================] - 0s 95ms/step - loss: 0.7765 - accuracy: 0.7500 - val_loss: 1.9028 - val_accuracy: 0.5000
# Epoch 105/150
# 4/4 [==============================] - ETA: 0s - loss: 0.9108 - accuracy: 0.5536
# Epoch 105: val_loss did not improve from 0.42847
# 4/4 [==============================] - 0s 106ms/step - loss: 0.9108 - accuracy: 0.5536 - val_loss: 0.6863 - val_accuracy: 0.8750
# Epoch 106/150
# 4/4 [==============================] - ETA: 0s - loss: 0.5813 - accuracy: 0.7857
# Epoch 106: val_loss did not improve from 0.42847
# 4/4 [==============================] - 0s 105ms/step - loss: 0.5813 - accuracy: 0.7857 - val_loss: 0.6226 - val_accuracy: 0.8750
# Epoch 106: early stopping

# %%
# Training curves
import matplotlib.pyplot as plt

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs_x = range(1, len(loss_values) + 1)
plt.figure(figsize=(10,10))
plt.subplot(2,1,1)
plt.plot(epochs_x, loss_values, 'bo', label='Training loss')
plt.plot(epochs_x, val_loss_values, 'b', label='Validation loss')
plt.title('Training and validation Loss and Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.subplot(2,1,2)
acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
plt.plot(epochs_x, acc_values, 'bo', label='Training acc')
plt.plot(epochs_x, val_acc_values, 'b', label='Validation acc')
#plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Acc')
plt.legend()
plt.show()

# %% [markdown]
# ## Evaluating the model

# %%
# Load the best saved model
from tensorflow.keras.models import load_model

model = load_model('model.keras')

# %%
# Using the validation dataset
score = model.evaluate(validation_generator)
print('Val loss:', score[0])
print('Val accuracy:', score[1])
# Out:
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4076 - accuracy: 0.9444
# Val loss: 0.4076269865036011
# Val accuracy: 0.9444444179534912

# %%
# Using the test dataset
score = model.evaluate(test_generator)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 2/2 [==============================] - 0s 13ms/step - loss: 1.0428 - accuracy: 0.7000
# Test loss: 1.0428444147109985
# Test accuracy: 0.699999988079071

# %%
import itertools

#Plot the confusion matrix. Set Normalize = True/False
def plot_confusion_matrix(cm, classes, normalize=True, title='Confusion matrix', cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize=(10,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        cm = np.around(cm, decimals=2)
        cm[np.isnan(cm)] = 0.0
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
# Some reports
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

#On test dataset
Y_pred = model.predict(test_generator)
y_pred = np.argmax(Y_pred, axis=1)
target_names = classes

#Confution Matrix
cm = confusion_matrix(test_generator.classes, y_pred)
plot_confusion_matrix(cm, target_names, normalize=False, title='Confusion Matrix')

#Classification Report
print('Classification Report')
print(classification_report(test_generator.classes, y_pred, target_names=target_names))
# Out:
# 2/2 [==============================] - 0s 169ms/step
# Classification Report
#               precision    recall  f1-score   support
#
#         acai       0.56      1.00      0.71         5
#      cupuacu       0.75      0.60      0.67         5
#     graviola       0.80      0.80      0.80         5
#      guarana       0.62      1.00      0.77         5
#      pupunha       1.00      0.40      0.57         5
#       tucuma       1.00      0.40      0.57         5
#
#     accuracy                           0.70        30
#    macro avg       0.79      0.70      0.68        30
# weighted avg       0.79      0.70      0.68        30
